# %% [markdown]
# # [Goulib](../notebook.ipynb).expr + polynomial
# Symbolic math expressions with LaTeX representation and plots
#
# [top notebook](../notebook.ipynb)

# %%
from Goulib.notebook import *
from Goulib.expr import *
from math import pi,sin

# %%
e1=Expr('3*x+2') #a very simple expression defined form text
print(e1) # Expr can be printed as text
e1 # but is rendered as laTeX by default
# Out:
# 3x+2
# 3*x+2

# %%
e1=Expr(lambda x:3*x+2) #the same expression defined from a lambda function
e1
# Out:
# 3*x+2

# %%
def f(x):
    return 3*x+2
g=f # this works because g is the same as f :-)
Expr(g) #the same expression defined from a regular (simple...) function
# Out:
# 3*x+2

# %%
e2=Expr(sin) # predefined functions also work !
e2
# Out:
# sin(x)

# %%
e3=e2(e1) #Expr can be composed
e3
# Out:
# sin(3*x+2)

# %%
print(e3(x=1)) # Expr can be evaluated as a function
print(e3((pi-4)/6)) #the x variable is implicit
# Out:
# -0.9589242746631385
# 1.0

# %%
e1([-2,1,0,1,2]) # Expr can be evaluated at different x values at once
# Out:
# [-4, 5, 2, 5, 8]

# %%
e3.plot()  # Expr can be also plotted

# %%
Expr('5**4+3')
# Out:
# 5**4+3

# %%
Expr('5**4+3')()
# Out:
# 628

# %%
e=Expr('a==a')
print(e,':',e())
# Out:
# a=a : True

# %%
#Expr can also be used to embellish float numbers:
Expr(math.sqrt(3))+Expr(1/5)
# Out:
# sqrt(3)+1/5

# %% [markdown]
# ## multivariable

# %%
e=Expr('sqrt(x*3+(a+b)*y)/x**(3*a*y)') #laTex is rendered with some simple simplifications
latex(e) #TODO : find why e default repr generates an error
# Out:
# $$\frac{\sqrt {3x+\left(a+b\right) \cdot y}}{x^{3a \cdot y}}$$

# %%
latex(e(a=1)) # substitution doesn't work yet ...
# Out:
# $$\frac{\sqrt {3x+\left(a+b\right) \cdot y}}{x^{3a \cdot y}}$$

# %% [markdown]
# ## Polynomial
#
# a Polynomial is an Expr defined by factors and with some more methods

# %%
from Goulib.polynomial import *

p1=Polynomial([-1,1,3]) # inited from coefficients in ascending power order
p1 # Latex output
# Out:
# 3*x**2+x-1

# %%
p2=Polynomial('3*x- 5x^3') # inited from string, in any power order, with optional spaces and *
p2.plot()

# %%
[(x,p1(x)) for x in itertools2.linspace(-1,1,11)] #evaluation
# Out:
# [(-1, 1),
#  (-0.8, 0.12000000000000033),
#  (-0.6000000000000001, -0.5199999999999998),
#  (-0.4000000000000001, -0.9199999999999999),
#  (-0.20000000000000007, -1.08),
#  (-5.551115123125783e-17, -1.0),
#  (0.19999999999999996, -0.6800000000000002),
#  (0.39999999999999997, -0.1200000000000001),
#  (0.6, 0.6800000000000002),
#  (0.8, 1.7200000000000006),
#  (1.0, 3.0)]

# %%
p1-p2+2 # addition and subtraction of polynomials and scalars
# Out:
# 5*x**3+3*x**2-2*x+1

# %%
-3*p1*p2**2 # polynomial (and scalar) multiplication and scalar power
# Out:
# -225*x**8-75*x**7+345*x**6+90*x**5-171*x**4-27*x**3+27*x**2

# %%
p1.derivative()+p2.integral() #integral and derivative
# Out:
# -1.25*x**4+1.5*x**2+6*x+1
